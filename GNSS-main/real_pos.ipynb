# %% [markdown]
# # Load data

# %%
#%matplotlib qt
import numpy as np
import pandas as pd
import os
# import keyboard
import matplotlib.pyplot as plt

from utils import * #ecef_to_llh, llh_to_ecef
from read_user import User
from read_obs import read_real_rover_obs, read_obs_data
from read_base import read_real_base_obs, parse_rinex_observation_data
# from EKF_utils import *

# %%
dir_path = os.getcwd()
data =  'RWD_20250422/D1T4' #'RWD_20250422/D1T4' 'YJN\Tightly_coupled_EKF-main' 'RWD_20250422/D2T10'
folder_path = os.path.join(dir_path, data)

''' Get User Position, IMU'''#读取 用户位置和IMU数据
user = User()
user.read_real_user_data(os.path.join(folder_path, 'user_pos.csv'), os.path.join(folder_path, 'imu_data.csv'))
origin = user.pos_llh[0, :] 

''' Read Base Observations '''#读取基站观测数据
base_obs = read_real_base_obs(os.path.join(folder_path, 'base_obs.csv'))

if 'D1' in data: # h + 45.5
    base_position, base_ecef = [48.0779195, 11.6305769, 549.51], False
    lte_tx1_llh = [48.0780113, 11.6307491, 549.40]
    lte_tx2_llh = [48.0778041, 11.6306888, 549.38]
    pl_tx1_llh = [48.0779030, 11.6309295, 551.38]
    pl_tx2_llh = [48.0781220, 11.6306068, 551.25]

elif 'D2' in data:
    base_position, base_ecef = [48.0779172, 11.6305752, 549.57], False
    lte_tx1_llh = [48.0780048, 11.6307446, 549.40]
    lte_tx2_llh = [48.0777902, 11.6306752, 549.42]
    pl_tx1_llh  = [48.0778883, 11.6309177, 551.56]
    pl_tx2_llh  = [48.0781255, 11.6306180, 551.40]
else:
    print("\033[31mError\033[0m: No transmitter data available for this dataset.")

lte_tx1_ecef = llh_to_ecef([lte_tx1_llh])[0]
lte_tx2_ecef = llh_to_ecef([lte_tx2_llh])[0]
pl_tx1_ecef = llh_to_ecef([pl_tx1_llh])[0]
pl_tx2_ecef = llh_to_ecef([pl_tx2_llh])[0]
TX_POS = {'L01': lte_tx1_ecef, 'L02': lte_tx2_ecef, 'P47': pl_tx1_ecef, 'P48': pl_tx2_ecef}

''' Read Rover Observations '''
rover_gnss = read_real_rover_obs(os.path.join(folder_path, 'rover_obs.csv'), TX_POS)

# print(pd.read_csv(os.path.join(folder_path, 'rover_obs_crop.csv'))['id'].unique())
# print(pd.read_csv(os.path.join(folder_path, 'rover_obs_crop.csv'))['sv_id'].unique())

# Get same time
np.set_printoptions(precision=10, suppress=False)
user_times = np.round(np.asarray(user.user['gps_time'].values, dtype=float), 1)
rover_obs_time = np.round(np.array(list(rover_gnss.keys()), dtype=float), 1)
overlapped_time, idx1, idx2 = np.intersect1d(user_times, rover_obs_time, return_indices=True)
# print(user_times[:10])
# print(rover_obs_time[:10])
# print(overlapped_time)
print(len(idx1), len(idx2))
print(max(user_times) - min(user_times), max(rover_obs_time) - min(rover_obs_time))
print("User time range:", min(user_times), max(user_times))
print("Rover time range:", min(rover_obs_time), max(rover_obs_time))
print("Overlapped time range:", min(overlapped_time), max(overlapped_time))
# Out:
# 716 716
# 111.0 83.10000014305115
# User time range: 1429364521.4 1429364632.4
# Rover time range: 1429364549.3 1429364632.4
# Overlapped time range: 1429364549.3 1429364632.4

# %%
unique_ids = {obs.id for obs_list in rover_gnss.values() for obs in obs_list}
print(sorted(unique_ids))

# print(user.user['gps_time'].values[:50]/1e9)
# Out:
# ['E05', 'E09', 'E15', 'E18', 'E21', 'E27', 'E30', 'E34', 'E36', 'G01', 'G02', 'G08', 'G10', 'G15', 'G16', 'G23', 'G27', 'G32', 'L01', 'L02', 'P47', 'P48']

# %%
# df = pd.read_csv(os.path.join(dir_path, 'learning/real_with_predicted_multipath.csv'))
df = pd.read_csv(os.path.join(dir_path, 'learning/real_with_predicted_multipath_svm_bal.csv'))
df = df.dropna()

print(df.head())
# Out:
#        gps_time satellite_id  sv_id   pseudorange  doppler_shift        cn0  \
# 0  1.429365e+09          G01      1  2.371945e+07   -3039.008006  42.975460
# 1  1.429365e+09          G02      2  2.160127e+07   -1837.173477  45.609964
# 2  1.429365e+09          G08      8  2.007511e+07    -926.014036  48.385704
# 3  1.429365e+09          G10     10  2.069873e+07     849.496573  48.685554
# 4  1.429365e+09          G23     23  2.277589e+07    3131.674603  39.140482
#
#       azimuth  elevation  pseudorange_residual  pseudorange_corrected_cb  \
# 0  262.633921  15.781663             -0.469555              2.409778e+07
# 1  277.053016  44.457877              0.041923              2.185358e+07
# 2  290.422082  66.985774             -0.611992              2.053719e+07
# 3   76.044600  65.665333              0.836119              2.088786e+07
# 4   47.377842  25.368725             -4.558627              2.322375e+07
#
#          sat_px        sat_py        sat_pz  sat_type    cn0_new  \
# 0  1.527411e+07 -2.033628e+07  7.613143e+06         0  42.975460
# 1  1.592333e+07 -1.252732e+07  1.739108e+07         0  45.609964
# 2  1.602714e+07 -4.383432e+06  2.065940e+07         0  48.385704
# 3  1.343987e+07  1.129458e+07  2.027075e+07         0  48.685554
# 4 -2.775320e+06  1.519344e+07  2.162021e+07         0  39.140482
#
#    predicted_multipath
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %%
# los_mask = df['predicted_multipath'] == 0
# nlos_mask = df['predicted_multipath'] == 1
gps_pl_mask = (df['sat_type'] == 0) | (df['sat_type'] == 1)
los_mask = (
    (df['predicted_multipath'] == 0) &
    ((df['sat_type'] == 0) | (df['sat_type'] == 1))
)
nlos_mask = (
    (df['predicted_multipath'] == 1) &
    ((df['sat_type'] == 0) | (df['sat_type'] == 1))
)

print("Total observations:", len(df))
print("GPS+PL observations:", len(df[gps_pl_mask]), " / ", len(df))
print("LOS observations:", len(df[los_mask]), " / ", len(df))
print("NLOS observations:", len(df[nlos_mask]), " / ", len(df))

# print(df.loc[los_mask, 'gps_time'].values[:50])

nlos_dict = (
    df.loc[df['predicted_multipath'] == 1]
      .groupby('gps_time')['satellite_id']
      .apply(list)       # or set
      .to_dict()
)

print(nlos_dict)

from collections import Counter

sat_count = Counter(sat_id for sats in nlos_dict.values() for sat_id in sats)
print(sat_count)

# rover_time = np.round(np.fromiter(rover_gnss.keys(), dtype=float), 1)
# for time, sats in nlos_dict.items():
#     if time not in rover_time:
#         print(f"Time {time} not in rover_gnss")
#         continue
#     idx = np.where(rover_time == time)[0]
#     key_list = list(rover_gnss.keys())
#     obs_key = key_list[idx[0]]   # since idx is usually a 1-element array
#     obs_list = rover_gnss[obs_key]
#     for sat in sats:
#         if sat not in [obs.id for obs in obs_list]:
#             print(f"Satellite {sat} not in observations at time {time}")
#             continue

# rover_gnss_los = {}

# for t, obs_list in rover_gnss.items():
#     t = round(t, 1)  # ensure matching precision
#     if t in nlos_dict:
#         nlos_sats = set(nlos_dict[t])
#         filtered_obs = [obs for obs in obs_list if obs.id not in nlos_sats]
#     else:
#         filtered_obs = obs_list  # no NLOS → keep all
#     rover_gnss_los[t] = filtered_obs

# print(df['gps_time'].unique())
# print(unique_times = df['gps_time'].unique())
# Out:
# Total observations: 11243
# GPS+PL observations: 6376  /  11243
# LOS observations: 4329  /  11243
# NLOS observations: 2047  /  11243
# {1429364549.3: ['G23'], 1429364549.4: ['G23'], 1429364549.5: ['G23'], 1429364549.6: ['G23'], 1429364549.7: ['G23'], 1429364549.8: ['G23'], 1429364549.9: ['G23'], 1429364550.2: ['G23'], 1429364550.3: ['G23'], 1429364550.4: ['G23'], 1429364550.5: ['G23'], 1429364550.6: ['G23'], 1429364550.7: ['G23'], 1429364550.8: ['G23'], 1429364550.9: ['G23'], 1429364551.0: ['G23'], 1429364551.2: ['G23'], 1429364551.3: ['G23'], 1429364551.4: ['G23'], 1429364551.5: ['G23', 'G32', 'P48'], 1429364551.6: ['G23', 'G32', 'P48'], 1429364551.7: ['G23', 'G32', 'P48'], 1429364551.8: ['G23', 'G32', 'P48'], 1429364551.9: ['G23', 'G32', 'P48'], 1429364552.0: ['G23', 'G32', 'P48'], 1429364552.2: ['G23', 'G32', 'P48'], 1429364552.3: ['G23', 'G32', 'P48'], 1429364552.4: ['G23', 'G32', 'P48'], 1429364552.5: ['G23', 'G32', 'P48'], 1429364552.6: ['G23', 'G32', 'P48'], 1429364552.7: ['G23', 'G32', 'P48'], 1429364552.8: ['G08', 'G23', 'G32', 'P48'], 1429364552.9: ['G08', 'G23', 'G32', 'P48'], 1429364553.0: ['G08', 'G23', 'G32', 'P48'], 1429364553.2: ['G08', 'G23', 'G32', 'P48'], 1429364553.3: ['G08', 'G23', 'G32', 'P48'], 1429364553.4: ['G08', 'G23', 'G32', 'P48'], 1429364553.5: ['G08', 'G23', 'G32', 'P48'], 1429364553.6: ['G08', 'G23', 'G32', 'P48'], 1429364553.7: ['G08', 'G23', 'G32', 'P48'], 1429364553.8: ['G08', 'G23', 'G32', 'P48'], 1429364553.9: ['G08', 'G23', 'G32', 'P48'], 1429364554.0: ['G08', 'G23', 'G32', 'P48'], 1429364554.2: ['G08', 'G23', 'G32', 'P48'], 1429364554.3: ['G08', 'G23', 'G32', 'P48'], 1429364554.4: ['G08', 'G23', 'G32', 'P48'], 1429364554.5: ['G08', 'G23', 'G32', 'P48'], 1429364554.6: ['G08', 'G23', 'G32', 'P48'], 1429364554.7: ['G08', 'G23', 'G32', 'P48'], 1429364554.8: ['G01', 'G08', 'G23', 'G32', 'P48'], 1429364554.9: ['G01', 'G08', 'G23', 'G32'], 1429364555.0: ['G01', 'G08', 'G23', 'G32'], 1429364555.2: ['G01', 'G08', 'G23', 'G32'], 1429364555.3: ['G01', 'G08', 'G23', 'G32'], 1429364555.4: ['G01', 'G08', 'G23', 'G32'], 1429364555.5: ['G01', 'G08', 'G23', 'G32'], 1429364555.6: ['G01', 'G08', 'G23', 'G32'], 1429364555.7: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364555.8: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364555.9: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.0: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.2: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.3: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.4: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.5: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.6: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.7: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.8: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364556.9: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.0: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.2: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.3: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.4: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.5: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.6: ['G01', 'G08', 'G10', 'G23', 'G32'], 1429364557.7: ['G01', 'G08', 'G23', 'G32'], 1429364557.8: ['G01', 'G08', 'G23', 'G32'], 1429364557.9: ['G01', 'G08', 'G23', 'G32'], 1429364558.2: ['G01', 'G08', 'G23'], 1429364558.3: ['G01', 'G08', 'G23'], 1429364558.4: ['G01', 'G08', 'G23'], 1429364558.5: ['G01', 'G08', 'G23'], 1429364558.6: ['G01', 'G08', 'G23'], 1429364558.7: ['G01', 'G08', 'G23'], 1429364558.8: ['G08', 'G23'], 1429364558.9: ['G08', 'G23'], 1429364559.0: ['G08', 'G23', 'P48'], 1429364559.2: ['G08', 'G23', 'P48'], 1429364559.3: ['G08', 'G23', 'P48'], 1429364559.4: ['G08', 'G23', 'P48'], 1429364559.5: ['G08', 'G23', 'P48'], 1429364559.6: ['G08', 'G23', 'P48'], 1429364559.7: ['G08', 'G23', 'G27', 'P48'], 1429364559.8: ['G08', 'G23', 'G27', 'P48'], 1429364559.9: ['G08', 'G23', 'G27', 'P48'], 1429364560.3: ['G08', 'G23', 'G27', 'P48'], 1429364560.4: ['G08', 'G23', 'G27', 'P48'], 1429364560.5: ['G08', 'G23', 'G27', 'P48'], 1429364560.6: ['G08', 'G23', 'G27', 'P48'], 1429364560.7: ['G08', 'G23', 'G27', 'P48'], 1429364560.8: ['G08', 'G23', 'G27', 'P48'], 1429364560.9: ['G ...
# Counter({'G23': 428, 'G32': 425, 'G01': 297, 'P48': 273, 'G08': 269, 'G16': 198, 'G27': 69, 'G02': 53, 'G10': 35, 'L02': 9})

# %%
CASES = {
    1 : [['C', 'E', 'P', 'L'], False],
    2 : [['C', 'E', 'L'], False],
    3 : [['C', 'E', 'P', 'L'], True],
    4 : [['C', 'E', 'L'], True],
}

sat_per_time = (
    df.groupby("gps_time")["satellite_id"]
      .apply(list)   # or .apply(set) if you want unique only
      .to_dict()
)

nlos_dict = (
    df.loc[df['predicted_multipath'] == 1]
      .groupby('gps_time')['satellite_id']
      .apply(list)       # or set
      .to_dict()
)



results = {}
for i, (exclude_id, exclude_NLOS) in CASES.items():
    estimated_ecef, estimated_cb, data = {}, {}, {}
    for time, sats in sat_per_time.items():
        data_obs, sat_positions, pseudoranges = [], [], []
        for sat in sats:
            if any(ex_id in sat for ex_id in exclude_id):
                continue
            if exclude_NLOS and time in nlos_dict and sat in nlos_dict[time]:
                print(f"Case {i}: Time {time}: Excluding NLOS satellite {sat}.")
                continue
            row = df[(df["gps_time"] == time) & (df["satellite_id"] == sat)].iloc[0]
            # print(row["sat_pos"], type(row["sat_pos"]))
            # split = first_satpos.replace('[','').replace(']','').split(',')
            # sat_positions.append([float(k) for k in row["sat_pos"].replace('[','').replace(']','').split(',')])
            sat_positions.append([float(row['sat_px']), float(row['sat_py']), float(row['sat_pz'])])
            pseudoranges.append(float(row["pseudorange_corrected_cb"]))
        if len(sat_positions) < 4:
            print(f"Case {i}: Time {time}: Not enough satellites after filtering. Needed 4, got {len(sat_positions)}.")
            continue
        # sat_positions = np.array(sat_positions, dtype=float).reshape(-1, 3)
        # pseudoranges = np.array(pseudoranges, dtype=float)
        receiver_position, clock_bias = single_point_positioning(
                sat_positions, pseudoranges, np.append(user.pos_ecef[0], 0)) 
        estimated_ecef[time] = receiver_position
        estimated_cb[time] = clock_bias

    overlapped_time, idx1, idx2 = np.intersect1d(user_times, np.array(list(estimated_ecef.keys())), return_indices=True)

    estimated_enu = {
            k: llh_to_enu(ecef_to_llh([v]), origin)
            for k, v in estimated_ecef.items() }
    
    results[i] = {
        'estimated_ecef': estimated_ecef, 
        'estimated_cb': estimated_cb,
        'estimated_enu': estimated_enu,
        'overlapped_time': overlapped_time,
        'idx1': idx1, # User time indices
        'idx2': idx2 # GNSS time indices
    }
# Out:
# Case 1: Time 1429364549.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364549.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364550.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364551.0: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364551.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364551.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 1: Time 1429364551.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364549.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364550.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364551.0: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364551.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364551.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 2: Time 1429364551.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364549.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.3: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.4: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.5: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.6: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.7: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.8: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364549.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364549.9: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.2: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.3: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.4: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.5: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.6: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.7: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.8: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364550.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364550.9: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364551.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.0: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364551.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.2: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364551.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.3: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364551.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.4: Not enough satellites after filtering. Needed 4, got 1.
# Case 3: Time 1429364551.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364551.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364551.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364551.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364551.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364551.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364552.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364552.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364552.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364552.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364553.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364553.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364553.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364554.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364554.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364554.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364554.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364554.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364554.9: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.0: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.2: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.3: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.4: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.5: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.6: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364555.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.7: Excluding NLOS satellite G10.
# Case 3: Time 1429364555.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364555.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.8: Excluding NLOS satellite G10.
# Case 3: Time 1429364555.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364555.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364555.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364555.9: Excluding NLOS satellite G10.
# Case 3: Time 1429364555.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364555.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364555.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.0: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.0: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.2: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.3: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.4: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.5: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.6: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.7: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.8: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364556.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364556.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364556.9: Excluding NLOS satellite G10.
# Case 3: Time 1429364556.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364556.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364556.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.0: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.0: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.2: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.3: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.4: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.5: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.6: Excluding NLOS satellite G10.
# Case 3: Time 1429364557.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364557.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364557.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364557.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364557.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364557.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364557.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364557.9: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364558.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364558.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364558.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364558.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.7: Excluding NLOS satellite G27.
# Case 3: Time 1429364559.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.8: Excluding NLOS satellite G27.
# Case 3: Time 1429364559.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364559.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364559.9: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.3: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.4: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.5: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.6: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.7: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.8: Excluding NLOS satellite G27.
# Case 3: Time 1429364560.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364560.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364560.9: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.0: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.2: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.3: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.4: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.5: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.6: Excluding NLOS satellite G27.
# Case 3: Time 1429364561.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364561.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364561.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364561.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.2: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.3: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.4: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.5: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.6: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364562.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364562.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364562.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364562.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364562.9: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.0: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.3: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.4: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.5: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.6: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364563.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.7: Excluding NLOS satellite G27.
# Case 3: Time 1429364563.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.7: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364563.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.8: Excluding NLOS satellite G27.
# Case 3: Time 1429364563.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.8: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364563.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364563.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364563.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364563.9: Excluding NLOS satellite G27.
# Case 3: Time 1429364563.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364563.9: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.2: Excluding NLOS satellite G27.
# Case 3: Time 1429364564.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.2: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.3: Excluding NLOS satellite G27.
# Case 3: Time 1429364564.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.3: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.4: Excluding NLOS satellite G27.
# Case 3: Time 1429364564.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.4: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.5: Excluding NLOS satellite G27.
# Case 3: Time 1429364564.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.5: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.6: Excluding NLOS satellite G27.
# Case 3: Time 1429364564.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.6: Not enough satellites after filtering. Needed 4, got 2.
# Case 3: Time 1429364564.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364564.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364564.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364564.9: Excluding NLOS satellite G08.
# Case 3: Time 1429364564.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364564.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364564.9: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.0: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.0: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.2: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.2: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.3: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.3: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.4: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.4: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.5: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.5: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.6: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.6: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.7: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364565.8: Excluding NLOS satellite G08.
# Case 3: Time 1429364565.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364565.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364565.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364565.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364566.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364566.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364566.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364567.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364567.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364567.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364567.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364567.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364568.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364568.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364568.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364569.0: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364569.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364569.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364569.9: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.2: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.3: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.4: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.5: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.6: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.7: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364570.7: Excluding NLOS satellite G27.
# Case 3: Time 1429364570.8: Excluding NLOS satellite G01.
# Case 3: Time 1429364570.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364570.8: Excluding NLOS satellite G27.
# Case 3: Time 1429364570.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364570.9: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.0: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.2: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.3: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.4: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.5: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.6: Excluding NLOS satellite G27.
# Case 3: Time 1429364571.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364571.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.7: Excluding NLOS satellite G16.
# Case 3: Time 1429364572.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.8: Excluding NLOS satellite G16.
# Case 3: Time 1429364572.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364572.9: Excluding NLOS satellite G02.
# Case 3: Time 1429364572.9: Excluding NLOS satellite G16.
# Case 3: Time 1429364572.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.0: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.0: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.2: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.2: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.2: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.3: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.3: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.3: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.4: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.4: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.4: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.5: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.5: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.5: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.6: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.6: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.6: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.7: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.7: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.7: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.8: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.8: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.8: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364573.9: Excluding NLOS satellite G02.
# Case 3: Time 1429364573.9: Excluding NLOS satellite G16.
# Case 3: Time 1429364573.9: Excluding NLOS satellite G23.
# Case 3: Time 1429364573.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364573.9: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364574.0: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.0: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.0: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364574.0: Not enough satellites after filtering. Needed 4, got 3.
# Case 3: Time 1429364574.2: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.2: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.2: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.3: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.3: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.3: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.4: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.4: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.4: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.5: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.5: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.5: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.6: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.6: Excluding NLOS satellite G16.
# Case 3: Time 1429364574.6: Excluding NLOS satellite G23.
# Case 3: Time 1429364574.7: Excluding NLOS satellite G02.
# Case 3: Time 1429364574.8: Excluding NLOS satellite G02.
# Case 3: Time 1429364575.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364575.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.3: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.4: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.5: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.6: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.7: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.8: Excluding NLOS satellite G32.
# Case 3: Time 1429364576.9: Excluding NLOS satellite G32.
# Case 3: Time 1429364577.0: Excluding NLOS satellite G32.
# Case 3: Time 1429364577.2: Excluding NLOS satellite G32.
# Case 3: Time 1429364577.3: Excluding NLOS satellite G32.
# ...
# Case 4: Time 1429364622.0: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.0: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.2: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.2: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.2: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.3: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.3: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.3: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.4: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.4: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.4: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.4: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.5: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.5: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.5: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.5: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.6: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.6: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.6: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.6: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G27.
# Case 4: Time 1429364622.7: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.7: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.7: Not enough satellites after filtering. Needed 4, got 3.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G27.
# Case 4: Time 1429364622.8: Excluding NLOS satellite G32.
# Case 4: Time 1429364622.8: Excluding NLOS satellite P48.
# Case 4: Time 1429364622.8: Not enough satellites after filtering. Needed 4, got 3.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G08.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G16.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G27.
# Case 4: Time 1429364622.9: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G08.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G23.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.0: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.2: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.2: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.3: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.3: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.4: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.4: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.4: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.5: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.5: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.5: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.6: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.6: Excluding NLOS satellite G27.
# Case 4: Time 1429364623.6: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.7: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.7: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.8: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.8: Excluding NLOS satellite G32.
# Case 4: Time 1429364623.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364623.9: Excluding NLOS satellite G16.
# Case 4: Time 1429364623.9: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.0: Excluding NLOS satellite G16.
# Case 4: Time 1429364624.0: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.4: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.5: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.6: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.7: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.8: Excluding NLOS satellite G32.
# Case 4: Time 1429364624.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364624.9: Excluding NLOS satellite G32.
# Case 4: Time 1429364625.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.0: Excluding NLOS satellite G32.
# Case 4: Time 1429364625.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.2: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364625.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.3: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364625.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.4: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.4: Excluding NLOS satellite G32.
# Case 4: Time 1429364625.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.5: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.6: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.7: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.8: Excluding NLOS satellite G16.
# Case 4: Time 1429364625.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364625.9: Excluding NLOS satellite G16.
# Case 4: Time 1429364626.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.0: Excluding NLOS satellite G16.
# Case 4: Time 1429364626.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.7: Excluding NLOS satellite G27.
# Case 4: Time 1429364626.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.8: Excluding NLOS satellite G27.
# Case 4: Time 1429364626.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364626.9: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.0: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.2: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.2: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.3: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.3: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.4: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.4: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.5: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.5: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.6: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.6: Excluding NLOS satellite G27.
# Case 4: Time 1429364627.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.7: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.8: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364627.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364627.9: Excluding NLOS satellite G08.
# Case 4: Time 1429364627.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.0: Excluding NLOS satellite G08.
# Case 4: Time 1429364628.0: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364628.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364628.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.0: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.2: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.2: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.3: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.3: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.4: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.4: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.5: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.5: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.5: Excluding NLOS satellite G32.
# Case 4: Time 1429364629.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.6: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.6: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.6: Excluding NLOS satellite G32.
# Case 4: Time 1429364629.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.7: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.7: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.7: Excluding NLOS satellite G32.
# Case 4: Time 1429364629.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.8: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.8: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.8: Excluding NLOS satellite G32.
# Case 4: Time 1429364629.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364629.9: Excluding NLOS satellite G02.
# Case 4: Time 1429364629.9: Excluding NLOS satellite G16.
# Case 4: Time 1429364629.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364629.9: Excluding NLOS satellite G32.
# Case 4: Time 1429364630.2: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.2: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364630.3: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.3: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364630.4: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.4: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.4: Excluding NLOS satellite G32.
# Case 4: Time 1429364630.5: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.5: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.6: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.6: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.7: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.7: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.8: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.8: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364630.9: Excluding NLOS satellite G01.
# Case 4: Time 1429364630.9: Excluding NLOS satellite G02.
# Case 4: Time 1429364630.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.0: Excluding NLOS satellite G01.
# Case 4: Time 1429364631.0: Excluding NLOS satellite G02.
# Case 4: Time 1429364631.0: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.2: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.3: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.4: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.5: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.5: Excluding NLOS satellite G32.
# Case 4: Time 1429364631.6: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.6: Excluding NLOS satellite G32.
# Case 4: Time 1429364631.7: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.7: Excluding NLOS satellite G32.
# Case 4: Time 1429364631.8: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.8: Excluding NLOS satellite G32.
# Case 4: Time 1429364631.9: Excluding NLOS satellite G23.
# Case 4: Time 1429364631.9: Excluding NLOS satellite G32.
# Case 4: Time 1429364632.0: Excluding NLOS satellite G23.
# Case 4: Time 1429364632.0: Excluding NLOS satellite G32.
# Case 4: Time 1429364632.2: Excluding NLOS satellite G32.
# Case 4: Time 1429364632.3: Excluding NLOS satellite G32.
# Case 4: Time 1429364632.4: Excluding NLOS satellite G32.

# %%
user_enu = llh_to_enu(user.pos_llh, origin)

for i in results.keys():
    print(f"Results for case {i}:")
    print(f"Estimated ECEF positions: {len(results[i]['estimated_ecef'])}")
    keys = list(results[i]['estimated_enu'].keys())
    enu_array = np.array([np.squeeze(results[i]['estimated_enu'][k]) for k in keys])
    error = np.linalg.norm(enu_array[results[i]['idx2'], :2] - user_enu[results[i]['idx1'], :2], axis=1)
    print("2D Error in enu:", np.mean(error))
    error = np.linalg.norm(enu_array[results[i]['idx2'], :] - user_enu[results[i]['idx1'], :], axis=1)
    print("3D Error in enu:", np.mean(error))
    print("\n")

#%matplotlib qt
plot_trajectory(
    {'user': user_enu,
        **{i: np.array([np.squeeze(v) for v in results[i]['estimated_enu'].values()])
            for i in results.keys()} }, 'Trajectories', 'enu', twoD=True, scatter=True
)

plt.show()
# Out:
# Results for case 1:
# Estimated ECEF positions: 697
# 2D Error in enu: 3.2631127376153586
# 3D Error in enu: 5.066412280713907
#
#
# Results for case 2:
# Estimated ECEF positions: 697
# 2D Error in enu: 3.3074822153855723
# 3D Error in enu: 3.9742629424159235
#
#
# Results for case 3:
# Estimated ECEF positions: 543
# 2D Error in enu: 8.573265043504955
# 3D Error in enu: 11.865798730586336
#
#
# Results for case 4:
# Estimated ECEF positions: 690
# 2D Error in enu: 5.1031871234586985
# 3D Error in enu: 6.390787139005938
